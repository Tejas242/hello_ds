# %%
import pandas as pd
import numpy as np
data = pd.read_csv('titanic3.csv')

# %%
data.replace('?', np.nan, inplace=True)
data = data.astype({"age": np.float64, "fare": np.float64})

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=5, figsize=(30, 5))
sns.violinplot(x='survived', y='age', hue='sex', data=data, ax=axs[0])
sns.pointplot(x="sibsp", y="survived", hue="sex", data=data, ax=axs[1])
sns.pointplot(x="parch", y="survived", hue="sex", data=data, ax=axs[2])
sns.pointplot(x="pclass", y="survived", hue="sex", data=data, ax=axs[3])
sns.violinplot(x="survived", y="fare", hue="sex", data=data, ax=axs[4])
# Out:
# <AxesSubplot: xlabel='survived', ylabel='fare'>

# %%
data.replace({'male': 1, 'female': 0}, inplace=True)

# %%
data.corr().abs()[['survived']]
# Out:
# C:\Users\tmaha\AppData\Local\Temp\ipykernel_13728\3910233885.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr().abs()[['survived']]
#           survived
# pclass    0.312469
# survived  1.000000
# sex       0.528693
# age       0.055512
# sibsp     0.027825
# parch     0.082660
# fare      0.244265
# body           NaN

# %%
data['relatives'] = data.apply(lambda row: int((row['sibsp'] + row['parch']) > 0), axis=1)
data.corr().abs()[['survived']]
# Out:
# C:\Users\tmaha\AppData\Local\Temp\ipykernel_13728\1678519043.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr().abs()[['survived']]
#            survived
# pclass     0.312469
# survived   1.000000
# sex        0.528693
# age        0.055512
# sibsp      0.027825
# parch      0.082660
# fare       0.244265
# body            NaN
# relatives  0.201719

# %%
data = data[['sex', 'pclass', 'age', 'relatives', 'fare', 'survived']].dropna()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[['sex', 'pclass', 'age', 'relatives', 'fare']], data['survived'], test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
from sklearn import metrics
predict_test = model.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, predict_test))
# Out:
# Accuracy: 0.7464114832535885

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()

# %%
model.add(Dense(5, kernel_initializer='uniform', activation='relu', input_dim=5))
model.add(Dense(5, kernel_initializer='uniform', activation='relu'))
model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 30
#
#  dense_1 (Dense)             (None, 5)                 30
#
#  dense_2 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 66
# Trainable params: 66
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, batch_size=32, epochs=50)
# Out:
# Epoch 1/50
# 27/27 [==============================] - 2s 3ms/step - loss: 0.6921 - accuracy: 0.5706
# Epoch 2/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6895 - accuracy: 0.5861
# Epoch 3/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6843 - accuracy: 0.6483
# Epoch 4/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6738 - accuracy: 0.7440
# Epoch 5/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6560 - accuracy: 0.7620
# Epoch 6/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6317 - accuracy: 0.7715
# Epoch 7/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6053 - accuracy: 0.7703
# Epoch 8/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5779 - accuracy: 0.7751
# Epoch 9/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5512 - accuracy: 0.7715
# Epoch 10/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5292 - accuracy: 0.7703
# Epoch 11/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5108 - accuracy: 0.7727
# Epoch 12/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.4972 - accuracy: 0.7703
# Epoch 13/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4869 - accuracy: 0.7739
# Epoch 14/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4785 - accuracy: 0.7751
# Epoch 15/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4729 - accuracy: 0.7775
# Epoch 16/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4691 - accuracy: 0.7811
# Epoch 17/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4661 - accuracy: 0.7811
# Epoch 18/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4633 - accuracy: 0.7847
# Epoch 19/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4619 - accuracy: 0.7847
# Epoch 20/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4604 - accuracy: 0.7823
# Epoch 21/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4588 - accuracy: 0.7835
# Epoch 22/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4575 - accuracy: 0.7847
# Epoch 23/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4567 - accuracy: 0.7823
# Epoch 24/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4558 - accuracy: 0.7859
# Epoch 25/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4552 - accuracy: 0.7835
# Epoch 26/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.4544 - accuracy: 0.7823
# Epoch 27/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4539 - accuracy: 0.7847
# Epoch 28/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4539 - accuracy: 0.7883
# Epoch 29/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4535 - accuracy: 0.7847
# Epoch 30/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4527 - accuracy: 0.7859
# Epoch 31/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4520 - accuracy: 0.7847
# Epoch 32/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4521 - accuracy: 0.7847
# Epoch 33/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4517 - accuracy: 0.7859
# Epoch 34/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4511 - accuracy: 0.7883
# Epoch 35/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4507 - accuracy: 0.7883
# Epoch 36/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4502 - accuracy: 0.7883
# Epoch 37/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4505 - accuracy: 0.7835
# Epoch 38/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4501 - accuracy: 0.7871
# Epoch 39/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4499 - accuracy: 0.7859
# Epoch 40/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4495 - accuracy: 0.7835
# Epoch 41/50
# 27/27 [==============================] - 0s 14ms/step - loss: 0.4493 - accuracy: 0.7823
# Epoch 42/50
# 27/27 [==============================] - 0s 7ms/step - loss: 0.4490 - accuracy: 0.7871
# Epoch 43/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4484 - accuracy: 0.7871
# Epoch 44/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4485 - accuracy: 0.7859
# Epoch 45/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4484 - accuracy: 0.7859
# Epoch 46/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4483 - accuracy: 0.7871
# Epoch 47/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.4474 - accuracy: 0.7859
# Epoch 48/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4472 - accuracy: 0.7835
# Epoch 49/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4471 - accuracy: 0.7859
# Epoch 50/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4468 - accuracy: 0.7847

# %%
y_pred = np.rint(model.predict(X_test).flatten())
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 7/7 [==============================] - 0s 3ms/step
# 0.7942583732057417
